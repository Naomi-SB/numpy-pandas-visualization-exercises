# %%
import matplotlib.pyplot as plt  

#import other libraries 
import numpy as np
import math
from random import randint
import random
import pandas as pd

# %%
x = range(10)
y1 = [(x**2) for x in x]
y2 = [(x**3) for x in x]

# %%
plt.plot(x, y1, y2)
# Out:
# [<matplotlib.lines.Line2D at 0x11f66c730>,
#  <matplotlib.lines.Line2D at 0x11f66c790>]

# %%
x = range(20)

plt.figure(figsize = (8,12))
plt.subplots(4, 2)

y1 = [(0*x +1)for x in x]
y2 = [(np.log(n))for n in x]
y3 = [(x)for x in x]

y5 = [(x **2)for x in x]

y8 = [(x**x) for x in x]

plt.subplot(221)
plt.plot(x,y1)
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.title('O1')

plt.subplot(222)
plt.plot(x, y2)
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.title('O(log n)')

plt.subplot(223)
plt.plot(x, y3)
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.title('O(n)')

plt.subplot(224)
plt.plot(x, y5)
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.title('O(2^n)')

plt.subplot(238)
plt.plot(x, y8)
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.title('O(n^n)')
plt.yscale('log')

fig.tight_layout()
plt.show()
# Out:
# /var/folders/h3/mf3_948d1xn0mgz6l997fvlw0000gn/T/ipykernel_25507/1211573814.py:7: RuntimeWarning: divide by zero encountered in log
#   y2 = [(np.log(n))for n in x]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [46], in <cell line: 38>()
#      35 plt.ylabel('Operations')
#      36 plt.title('O(2^n)')
# ---> 38 plt.subplot(238)
#      39 plt.plot(x, y8)
#      40 plt.xlabel('Elements')
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:1268, in subplot(*args, **kwargs)
#    1265 fig = gcf()
#    1267 # First, search for an existing subplot with a matching spec.
# -> 1268 key = SubplotSpec._from_subplot_args(fig, args)
#    1270 for ax in fig.axes:
#    1271     # if we found an axes at the position sort out if we can re-use it
#    1272     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1273         # if the user passed no kwargs, re-use
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib/gridspec.py:608, in SubplotSpec._from_subplot_args(figure, args)
#     606 else:
#     607     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 608         raise ValueError(
#     609             f"num must be 1 <= num <= {rows*cols}, not {num!r}")
#     610     i = j = num
#     611 return gs[i-1:j]
#
# ValueError: num must be 1 <= num <= 6, not 8

# %%
#y2 = [(log(n))for n in x]

y2 = [(np.log(n))for n in x]
plt.plot(x, y2)
# Out:
# /var/folders/h3/mf3_948d1xn0mgz6l997fvlw0000gn/T/ipykernel_25507/2786257395.py:3: RuntimeWarning: divide by zero encountered in log
#   y = [(np.log(n))for n in x]

# %%
#y4 = [(n * log(n))for n in x]

# %%
#y7 = [(fact * n)for n in x]
